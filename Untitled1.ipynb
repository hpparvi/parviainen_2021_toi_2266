# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run toi_2266.py

# %%
times, fluxes, covs = [], [], []

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-SSO-2m0_gp_Measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-SSO-2m0_rp_Measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-SSO-2m0_ip_Measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-SSO-2m0_zs_Measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)
# Out:
# (None, None)

# %%
df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-HAL-M3_gp_10px_measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-HAL-M3_rp_15px_measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-HAL-M3_ip_15px_measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)

df = pd.read_csv('data/external/TIC8348911-01_20210523_LCO-HAL-M3_zs_15px_measurements.tbl', delim_whitespace=True)
t = df.BJD_TDB.values.copy()
f = df.rel_flux_T1.values.copy()
c = df['AIRMASS FWHM_Mean X(IJ)_T1 Y(IJ)_T1'.split()].values.copy()
times.append(t); fluxes.append(f), covs.append(c)
# Out:
# (None, None)

# %%
plot(times[0], fluxes[0])

# %%
df.columns.values
# Out:
# array(['Label', 'slice', 'Saturated', 'J.D.-2400000', 'JD_UTC', 'JD_SOBS',
#        'JD_MOBS', 'HJD_MOBS', 'BJD_MOBS', 'ALT_OBJ', 'AIRMASS',
#        'FWHM_Mean', 'Source_Radius', 'Sky_Rad(min)', 'Sky_Rad(max)',
#        'rel_flux_T1', 'rel_flux_C2', 'rel_flux_C3', 'rel_flux_C4',
#        'rel_flux_T5', 'rel_flux_T6', 'rel_flux_C7', 'rel_flux_C8',
#        'rel_flux_err_T1', 'rel_flux_err_C2', 'rel_flux_err_C3',
#        'rel_flux_err_C4', 'rel_flux_err_T5', 'rel_flux_err_T6',
#        'rel_flux_err_C7', 'rel_flux_err_C8', 'rel_flux_SNR_T1',
#        'rel_flux_SNR_C2', 'rel_flux_SNR_C3', 'rel_flux_SNR_C4',
#        'rel_flux_SNR_T5', 'rel_flux_SNR_T6', 'rel_flux_SNR_C7',
#        'rel_flux_SNR_C8', 'tot_C_cnts', 'tot_C_err', 'X(IJ)_T1',
#        'Y(IJ)_T1', 'X(FITS)_T1', 'Y(FITS)_T1', 'RA_T1', 'DEC_T1',
#        'Source-Sky_T1', 'N_Src_Pixels_T1', 'Source_Error_T1',
#        'Source_SNR_T1', 'Peak_T1', 'Mean_T1', 'Sky/Pixel_T1',
#        'N_Sky_Pixels_T1', 'FWHM_T1', 'Width_T1', 'X-Width_T1',
#        'Y-Width_T1', 'Angle_T1', 'Roundness_T1', 'Variance_T1',
#        'X(IJ)_C2', 'Y(IJ)_C2', 'X(FITS)_C2', 'Y(FITS)_C2', 'RA_C2',
#        'DEC_C2', 'Source-Sky_C2', 'Source_Error_C2', 'Source_SNR_C2',
#        'Peak_C2', 'Mean_C2', 'Sky/Pixel_C2', 'FWHM_C2', 'Width_C2',
#        'X-Width_C2', 'Y-Width_C2', 'Angle_C2', 'Roundness_C2',
#        'Variance_C2', 'X(IJ)_C3', 'Y(IJ)_C3', 'X(FITS)_C3', 'Y(FITS)_C3',
#        'RA_C3', 'DEC_C3', 'Source-Sky_C3', 'Source_Error_C3',
#        'Source_SNR_C3', 'Peak_C3', 'Mean_C3', 'Sky/Pixel_C3', 'FWHM_C3',
#        'Width_C3', 'X-Width_C3', 'Y-Width_C3', 'Angle_C3', 'Roundness_C3',
#        'Variance_C3', 'X(IJ)_C4', 'Y(IJ)_C4', 'X(FITS)_C4', 'Y(FITS)_C4',
#        'RA_C4', 'DEC_C4', 'Source-Sky_C4', 'Source_Error_C4',
#        'Source_SNR_C4', 'Peak_C4', 'Mean_C4', 'Sky/Pixel_C4', 'FWHM_C4',
#        'Width_C4', 'X-Width_C4', 'Y-Width_C4', 'Angle_C4', 'Roundness_C4',
#        'Variance_C4', 'X(IJ)_T5', 'Y(IJ)_T5', 'X(FITS)_T5', 'Y(FITS)_T5',
#        'RA_T5', 'DEC_T5', 'Source-Sky_T5', 'Source_Error_T5',
#        'Source_SNR_T5', 'Peak_T5', 'Mean_T5', 'Sky/Pixel_T5', 'FWHM_T5',
#        'Width_T5', 'X-Width_T5', 'Y-Width_T5', 'Angle_T5', 'Roundness_T5',
#        'Variance_T5', 'X(IJ)_T6', 'Y(IJ)_T6', 'X(FITS)_T6', 'Y(FITS)_T6',
#        'RA_T6', 'DEC_T6', 'Source-Sky_T6', 'Source_Error_T6',
#        'Source_SNR_T6', 'Peak_T6', 'Mean_T6', 'Sky/Pixel_T6', 'FWHM_T6',
#        'Width_T6', 'X-Width_T6', 'Y-Width_T6', 'Angle_T6', 'Roundness_T6',
#        'Variance_T6', 'X(IJ)_C7', 'Y(IJ)_C7', 'X(FITS)_C7', 'Y(FITS)_C7',
#        'RA_C7', 'DEC_C7', 'Source-Sky_C7', 'Source_Error_C7',
#        'Source_SNR_C7', 'Peak_C7', 'Mean_C7', 'Sky/Pixel_C7', 'FWHM_C7',
#        'Width_C7', 'X-Width_C7', 'Y-Width_C7', 'Angle_C7', 'Roundness_C7',
#        'Variance_C7', 'X(IJ)_C8', 'Y(IJ)_C8', 'X(FITS)_C8', 'Y(FITS)_C8',
#        'RA_C8', 'DEC_C8', 'Source-Sky_C8', 'Source_Error_C8',
#        'Source_SNR_C8', 'Peak_C8', 'Mean_C8', 'Sky/Pixel_C8', 'FWHM_C8',
#        'Width_C8', 'X-Width_C8', 'Y-Width_C8', 'Angle_C8', 'Roundness_C8',
#        'Variance_C8', 'BJD_TDB'], dtype=object)
